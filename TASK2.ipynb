# %%
import pandas as pd

# Specify the new file paths
train_file_path = r'C:\Users\ADMINI\Desktop\train.csv'
test_file_path = r'C:\Users\ADMINI\Desktop\test.csv'
submission_file_path = r'C:\Users\ADMINI\Desktop\gender_submission.csv'

# Load the Titanic dataset
data1 = pd.read_csv(train_file_path)
data2 = pd.read_csv(test_file_path)
data3 = pd.read_csv(submission_file_path)

# Calculate summary statistics for the train dataset
mean_values = data1.mean()
median_values = data1.median()
mode_values = data1.mode().iloc[0]
std_values = data1.std()

# Display the summary statistics
print("Summary Statistics for Train Dataset:")
print("Mean:")
print(mean_values)
print("\nMedian:")
print(median_values)
print("\nMode:")
print(mode_values)
print("\nStandard Deviation:")
print(std_values)
# Out:
# Summary Statistics for Train Dataset:
# Mean:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64
#
# Median:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64
#
# Mode:
# PassengerId                      1
# Survived                       0.0
# Pclass                         3.0
# Name           Abbing, Mr. Anthony
# Sex                           male
# Age                           24.0
# SibSp                          0.0
# Parch                          0.0
# Ticket                        1601
# Fare                          8.05
# Cabin                      B96 B98
# Embarked                         S
# Name: 0, dtype: object
#
# Standard Deviation:
# ...

# %%
import pandas as pd

# Specify the new file paths
train_file_path = r'C:\Users\ADMINI\Desktop\train.csv'
test_file_path = r'C:\Users\ADMINI\Desktop\test.csv'
submission_file_path = r'C:\Users\ADMINI\Desktop\gender_submission.csv'

# Load the Titanic datasets
data1 = pd.read_csv(train_file_path)
data2 = pd.read_csv(test_file_path)
data3 = pd.read_csv(submission_file_path)

# Calculate summary statistics for the test dataset
mean_values = data2.mean()
median_values = data2.median()
mode_values = data2.mode().iloc[0]
std_values = data2.std()

# Displaying the summary statistics
print("Summary Statistics for Test Dataset:")
print("Mean:")
print(mean_values)
print("\nMedian:")
print(median_values)
print("\nMode:")
print(mode_values)
print("\nStandard Deviation:")
print(std_values)
# Out:
# Summary Statistics for Test Dataset:
# Mean:
# PassengerId    1100.500000
# Pclass            2.265550
# Age              30.272590
# SibSp             0.447368
# Parch             0.392344
# Fare             35.627188
# dtype: float64
#
# Median:
# PassengerId    1100.5000
# Pclass            3.0000
# Age              27.0000
# SibSp             0.0000
# Parch             0.0000
# Fare             14.4542
# dtype: float64
#
# Mode:
# PassengerId                              892
# Pclass                                   3.0
# Name           Abbott, Master. Eugene Joseph
# Sex                                     male
# Age                                     21.0
# SibSp                                    0.0
# Parch                                    0.0
# Ticket                              PC 17608
# Fare                                    7.75
# Cabin                        B57 B59 B63 B66
# Embarked                                   S
# Name: 0, dtype: object
#
# ...

# %%
import pandas as pd

# Specify the new file paths
train_file_path = r'C:\Users\ADMINI\Desktop\train.csv'
test_file_path = r'C:\Users\ADMINI\Desktop\test.csv'
submission_file_path = r'C:\Users\ADMINI\Desktop\gender_submission.csv'

# Load the Titanic datasets
data1 = pd.read_csv(train_file_path)
data2 = pd.read_csv(test_file_path)
data3 = pd.read_csv(submission_file_path)

# Calculate summary statistics for the gender submission dataset
mean_values = data3.mean()
median_values = data3.median()
mode_values = data3.mode().iloc[0]
std_values = data3.std()

# Display the summary statistics
print("Summary Statistics for Gender Submission Dataset:")
print("Mean:")
print(mean_values)
print("\nMedian:")
print(median_values)
print("\nMode:")
print(mode_values)
print("\nStandard Deviation:")
print(std_values)
# Out:
# Summary Statistics for Gender Submission Dataset:
# Mean:
# PassengerId    1100.500000
# Survived          0.363636
# dtype: float64
#
# Median:
# PassengerId    1100.5
# Survived          0.0
# dtype: float64
#
# Mode:
# PassengerId    892.0
# Survived         0.0
# Name: 0, dtype: float64
#
# Standard Deviation:
# PassengerId    120.810458
# Survived         0.481622
# dtype: float64
